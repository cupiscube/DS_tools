# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings("ignore")

plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

# %%
# ! pip install xgboost

# %%
def score_dataset(X, y, model=XGBRegressor(random_state=0)):
    score = cross_val_score(
        model, X, y, cv=5, scoring="neg_mean_absolute_error",
    )
    
    return -score.mean()

# %%
df = pd.read_csv("data/ames.csv")

# %%
df.describe(include='all')
# Out:
#                                  MSSubClass                 MSZoning  \
# count                                  2930                     2930
# unique                                   16                        7
# top     One_Story_1946_and_Newer_All_Styles  Residential_Low_Density
# freq                                   1079                     2273
# mean                                    NaN                      NaN
# std                                     NaN                      NaN
# min                                     NaN                      NaN
# 25%                                     NaN                      NaN
# 50%                                     NaN                      NaN
# 75%                                     NaN                      NaN
# max                                     NaN                      NaN
#
#         LotFrontage        LotArea Street            Alley LotShape  \
# count   2930.000000    2930.000000   2930             2930     2930
# unique          NaN            NaN      2                3        4
# top             NaN            NaN   Pave  No_Alley_Access  Regular
# freq            NaN            NaN   2918             2732     1859
# mean      57.647782   10147.921843    NaN              NaN      NaN
# std       33.499441    7880.017759    NaN              NaN      NaN
# min        0.000000    1300.000000    NaN              NaN      NaN
# 25%       43.000000    7440.250000    NaN              NaN      NaN
# 50%       63.000000    9436.500000    NaN              NaN      NaN
# 75%       78.000000   11555.250000    NaN              NaN      NaN
# max      313.000000  215245.000000    NaN              NaN      NaN
#
#        LandContour Utilities LotConfig  ...     PoolArea   PoolQC     Fence  \
# count         2930      2930      2930  ...  2930.000000     2930      2930
# unique           4         3         5  ...          NaN        5         5
# top            Lvl    AllPub    Inside  ...          NaN  No_Pool  No_Fence
# freq          2633      2927      2140  ...          NaN     2917      2358
# mean           NaN       NaN       NaN  ...     2.243345      NaN       NaN
# std            NaN       NaN       NaN  ...    35.597181      NaN       NaN
# min            NaN       NaN       NaN  ...     0.000000      NaN       NaN
# 25%            NaN       NaN       NaN  ...     0.000000      NaN       NaN
# 50%            NaN       NaN       NaN  ...     0.000000      NaN       NaN
# 75%            NaN       NaN       NaN  ...     0.000000      NaN       NaN
# max            NaN       NaN       NaN  ...   800.000000      NaN       NaN
#
#        MiscFeature       MiscVal       MoSold     YearSold SaleType  \
# count          106   2930.000000  2930.000000  2930.000000     2930
# unique           5           NaN          NaN          NaN       10
# top           Shed           NaN          NaN          NaN      WD
# freq            95           NaN          NaN          NaN     2536
# mean           NaN     50.635154     6.216041  2007.790444      NaN
# std            NaN    566.344288     2.714492     1.316613      NaN
# min            NaN      0.000000     1.000000  2006.000000      NaN
# 25%            NaN      0.000000     4.000000  2007.000000      NaN
# 50%            NaN      0.000000     6.000000  2008.000000      NaN
# 75%            NaN      0.000000     8.000000  2009.000000      NaN
# max            NaN  17000.000000    12.000000  2010.000000      NaN
#
#         SaleCondition      SalePrice
# count            2930    2930.000000
# unique              6            NaN
# top            Normal            NaN
# freq             2413            NaN
# mean              NaN  180796.060068
# std               NaN   79886.692357
# min               NaN   12789.000000
# 25%               NaN  129500.000000
# 50%               NaN  160000.000000
# 75%               NaN  213500.000000
# max               NaN  755000.000000
#
# [11 rows x 79 columns]

# %% [markdown]
# ## Выбор фич для PCA

# %%
df.corrwith(df.SalePrice, numeric_only=True).sort_values()
# Out:
# BsmtFinSF1         -0.134905
# EnclosedPorch      -0.128787
# KitchenAbvGr       -0.119814
# LowQualFinSF       -0.037660
# BsmtHalfBath       -0.035817
# YearSold           -0.030569
# MiscVal            -0.015691
# BsmtFinSF2          0.006018
# Threeseasonporch    0.032225
# MoSold              0.035259
# PoolArea            0.068403
# ScreenPorch         0.112151
# BedroomAbvGr        0.143913
# BsmtUnfSF           0.183308
# LotFrontage         0.201875
# LotArea             0.266549
# SecondFlrSF         0.269373
# BsmtFullBath        0.275823
# HalfBath            0.285056
# OpenPorchSF         0.312951
# WoodDeckSF          0.327143
# Fireplaces          0.474558
# TotRmsAbvGrd        0.495474
# MasVnrArea          0.502196
# YearRemodAdd        0.532974
# FullBath            0.545604
# YearBuilt           0.558426
# FirstFlrSF          0.621676
# TotalBsmtSF         0.632529
# GarageArea          0.640138
# GarageCars          0.647562
# GrLivArea           0.706780
# SalePrice           1.000000
# dtype: float64

# %%
features = [
    "GarageArea",
    "YearBuilt",
    "TotalBsmtSF",
    "GrLivArea",
]

print("Correlation with SalePrice:\n")
print(df[features].corrwith(df.SalePrice))
# Out:
# Correlation with SalePrice:
#
# GarageArea     0.640138
# YearBuilt      0.558426
# TotalBsmtSF    0.632529
# GrLivArea      0.706780
# dtype: float64

# %% [markdown]
# ## Применение PCA

# %%
X = df.copy()
y = X.pop("SalePrice")
X = X.loc[:, features]

# Стандартизация
X_stand = (X - X.mean(axis=0)) / X.std(axis=0)

pca = PCA()
X_pca = pca.fit_transform(X_stand)

# Переводим результат в Pandas Dataframe
component_names = [f"PC{i+1}" for i in range(X_pca.shape[1])]
X_pca = pd.DataFrame(X_pca, columns=component_names)
# В loading записываем "смысловую нагрузку" компонент, их корреляцию с исходными
loadings = pd.DataFrame(
    pca.components_.T,
    columns=component_names,
    index=X.columns,
)

print(loadings)
# Out:
#                   PC1       PC2       PC3       PC4
# GarageArea   0.546548 -0.035684 -0.424831  0.720784
# YearBuilt    0.458738 -0.735865 -0.152473 -0.474146
# TotalBsmtSF  0.517214  0.076507  0.845324  0.109835
# GrLivArea    0.472582  0.671845 -0.285829 -0.493551

# %%
GrLivArea / YearBuilt 
больше, если дом большой и старый
меньше, если дом маленький и новый

# %% [markdown]
# ## Интерпретация и оценка

# %%
X = df[features].copy()
y = df.SalePrice.copy()

X = X.join(X_pca.PC1)
X['Large_old'] = X.GrLivArea / X.YearBuilt

score = score_dataset(X, y)
print(score)
# Out:
# 22930.35359694966

# %% [markdown]
# ## Применение PCA для поиска выбросов

# %%
sns.catplot(
    y="value",
    col="variable",
    data=X_pca.melt(),
    kind='boxen',
    sharey=False,
    col_wrap=2,
);

# %%
component = "PC3"

idx = X_pca[component].sort_values(ascending=False).index
df.loc[idx, ["SalePrice", "SaleCondition"] + features]
# Out:
#       SalePrice SaleCondition  GarageArea  YearBuilt  TotalBsmtSF  GrLivArea
# 1498     160000       Partial      1418.0       2008       6110.0     5642.0
# 2180     183850       Partial      1154.0       2008       5095.0     5095.0
# 444      284000        Normal       880.0       2003       3206.0     1629.0
# 1772     430000        Normal       546.0       1992       3200.0     3228.0
# 423      555000        Normal       672.0       2008       3094.0     2402.0
# ...         ...           ...         ...        ...          ...        ...
# 887      198500        Normal       672.0       2003          0.0     1922.0
# 1945     301600        Family      1200.0       1935        666.0     3086.0
# 809      147983        Alloca       720.0       1979          0.0     2228.0
# 2278     130000        Normal      1041.0       1953          0.0     2034.0
# 1497     284700        Normal       624.0       1959          0.0     3820.0
#
# [2930 rows x 6 columns]

# %%
df.SaleType.value_counts()
# Out:
# SaleType
# WD       2536
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# VWD         1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Дисперсия, объясняемая PCA

# %%
fig, axs = plt.subplots(1, 2)
n = pca.n_components_
grid = np.arange(1, n + 1)

evr = pca.explained_variance_ratio_ 
axs[0].bar(grid, evr)
axs[0].set(xlabel="Component", title="% Explained Variance", ylim=(0.0, 1.0))

# Кумулятивная дисперсия (variance)
cv = np.cumsum(evr) 
axs[1].plot(np.r_[0, grid], np.r_[0, cv], "o-")
axs[1].set(xlabel="Component", title="% Cumulative Variance", ylim=(0.0, 1.0))

fig.set(figwidth=8, dpi=100)
# Out:
# [None, None]

# %%
99% 
95% - 5%
< 90%
