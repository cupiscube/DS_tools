# %%
pip install opencv-python
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   ERROR: Command errored out with exit status 1:
# ...
# Failed to build opencv-python
#    command: 'c:\users\danil\appdata\local\programs\python\python36\python.exe' 'c:\users\danil\appdata\local\programs\python\python36\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\Danil\AppData\Local\Temp\tmp93hxq6w4'
#        cwd: C:\Users\Danil\AppData\Local\Temp\pip-install-71dgagq4\opencv-python_6c93959e816d453f8c92f2bf8776192f
#   Complete output (395 lines):
#
#
#   --------------------------------------------------------------------------------
#   -- Trying 'Ninja (Visual Studio 17 2022 x64 v143)' generator
# ...
