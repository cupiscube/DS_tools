# %% [markdown]
# # Самая простая нейросеть
#
# Самой простой из возможных конфигураций нейросетей является один нейрон с одним входом и одним выходом без активации (или можно сказать с линейной активацией f(x) = x)

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return 2 * x + 5

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense

def baseline_model():
    model = Sequential()
    model.add(Dense(1, input_dim=1, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer='sgd')
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=10, verbose = 0)
model.fit(x, y, epochs=100, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# 32/32 [==============================] - 0s 763us/step
# [array([[1.9999999]], dtype=float32), array([4.999989], dtype=float32)]

# %% [markdown]
# # Решаем более полную задачу
# Попробуем теперь усложнить задачу, взяв более сложную функцию:
#
# 2 * np.sin(x) + 5

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return 2 * np.sin(x) + 5

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense

def baseline_model():
    model = Sequential()
    model.add(Dense(1, input_dim=1, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer='sgd')
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=100, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# [array([[0.7013333]], dtype=float32), array([5.0026746], dtype=float32)]

# %% [markdown]
# В выводе параметров сети первое число — это вес w, второе — смещение b.
# Чтобы убедиться в этом, давайте нарисуем прямую
#
# f(x) = w * x + b:

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return 2 * np.sin(x) + 5

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense

def baseline_model():
    model = Sequential()
    model.add(Dense(1, input_dim=1, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer='sgd')
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=100, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
    
def line(x):
    w = model.layers[0].get_weights()[0][0][0]
    b = model.layers[0].get_weights()[1][0]
    
    return w * x + b

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=3, antialiased=True)
plt.plot(x, line(x), color='yellow', linewidth=1, antialiased=True)
plt.show()
# Out:
# [array([[0.70657367]], dtype=float32), array([5.0019097], dtype=float32)]

# %% [markdown]
# # Работа с функцией активации
# Чтобы сделать прогноз более точным, используем в нейронах внутреннего слоя функцию активации ReLU
# Данное решение позволяет сети "сломать" прямую на сегменты.
# Поэкспериментируем с числом нейронов скрытого слоя

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return 2 * np.sin(x) + 5

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(20, input_dim=1, activation='relu'))
    model.add(Dense(1, input_dim=20, activation='linear'))
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# 32/32 [==============================] - 0s 860us/step
# [array([[ 0.4445409 ,  0.07145599,  0.29889607, -0.25568017, -0.7818259 ,
#          0.18275282, -0.03952887,  0.45455664,  0.9312259 ,  1.1120943 ,
#         -0.55882645,  0.21923319, -0.14987281,  0.53933924, -0.7804218 ,
#          0.0182246 ,  0.44593874,  0.10182721, -0.04699529, -0.01579951]],
#       dtype=float32), array([ 1.080674  ,  0.18508154,  0.61314154,  0.8771275 , -0.51089495,
#         0.47301614,  0.1353318 ,  1.0015748 , -1.7682061 , -1.0871693 ,
#        -0.8253646 ,  0.4398656 ,  0.36038357,  0.9248312 , -0.83935714,
#        -0.12808797,  0.84708637,  0.2635864 , -0.29444253, -0.41870448],
#       dtype=float32)]
# [array([[ 0.73934174],
#        [ 0.24470006],
#        [ 0.5519264 ],
#        [-0.27231967],
#        [ 0.5876332 ],
#        [ 0.47068444],
#        [-0.04176243],
#        [ 0.701136  ],
#        [-1.8671327 ],
#        [-1.4347442 ],
#        [ 0.99230593],
#        [ 0.34264883],
#        [-0.18230753],
#        [ 0.7845208 ],
#        [ 1.1407571 ],
#        [ 0.06781312],
#        [ 0.66223603],
#        [ 0.29905355],
#        [ 0.12297077],
#        [-0.4071232 ]], dtype=float32), array([1.6640157], dtype=float32)]

# %% [markdown]
# # Усложняем функцию
# Синус — довольно удачная функция для оптимизации. Главным образом потому, что у него нет широких плато — т.е. областей, где функция изменяется очень медленно. К тому же сама функция изменяется довольно равномерно.
# Чтобы проверить нашу конфигурацию нейросети на работоспособность, возьмём более сложную функцию:
#
# x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)
#
# Здесь также поработаем с размером скрытого слоя

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(40, input_dim=1, activation='relu'))
    model.add(Dense(1, input_dim=40, activation='linear'))
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# 32/32 [==============================] - 0s 954us/step
# [array([[-1.3362881 , -0.59261614,  0.00979265,  0.24226007,  1.6423249 ,
#         -0.08192385,  0.6203596 , -0.21621323, -4.527705  , -0.77395815,
#          0.8862292 , -3.4655888 , -0.10525315,  0.61911774, -0.44724545,
#          1.3969136 , -0.06366863,  0.5875892 ,  0.49053568, -1.0082891 ,
#          0.07805588,  0.64706445,  0.3108601 ,  0.40529048,  0.9594737 ,
#          1.039586  ,  0.72856265,  1.36315   , -0.39522585, -2.2863069 ,
#          0.77388054,  1.1863595 , -0.6436163 ,  0.19982971,  0.33364406,
#         -2.7334313 ,  1.1527319 , -0.8906316 , -0.4369623 , -0.05539932]],
#       dtype=float32), array([-2.988632  , -1.3255007 , -0.04861961, -0.11529164, -2.441838  ,
#        -0.39496538, -0.29523844,  0.5125252 , -8.099491  , -1.7309525 ,
#        -0.62676936, -7.752693  ,  0.25040376, -0.43757495,  1.064022  ,
#        -2.0791457 , -0.3143779 , -0.4162631 , -0.346677  , -2.2552922 ,
#        -0.0552984 , -0.96309495, -0.23000666, -0.60260665, -0.67789966,
#        -1.5474019 , -0.51488   , -2.0290196 , -1.2785692 , -5.1133    ,
#        -0.54678756, -1.7639006 , -2.0824714 , -0.1476805 , -0.2357857 ,
#        -3.6709433 , -0.54863274, -1.1960164 , -0.9766972 , -0.2620034 ],
#       dtype=float32)]
# [array([[-0.83848673],
#        [-0.37151936],
#        [ 0.15370707],
#        [ 0.16886345],
#        [-0.7780682 ],
#        [-0.2593801 ],
#        [ 0.43240753],
#        [ 0.3445307 ],
#        [ 2.5973837 ],
#        [-0.48564547],
#        [ 0.5791336 ],
#        [-2.177345  ],
#        [ 0.16884938],
#        [ 0.40486515],
#        [ 0.7174802 ],
#        [-0.6622068 ],
#        [-0.20931587],
#        [ 0.38377354],
#        [ 0.32078794],
#        [-0.6323662 ],
#        [ 0.05098015],
#        [-0.30673695],
#        [ 0.1952319 ],
#        [-0.19200596],
#        [ 0.6274667 ],
#        [-0.49277836],
#        [ 0.47645336],
#        [-0.646152  ],
#        [-0.977735  ],
#        [-1.434616  ],
#        [ 0.50608814],
#        [-0.56204885],
#        [-1.5429206 ],
#        [ 0.12578012],
#        [ 0.21819201],
#        [-1.5691382 ],
#        [ 0.8034724 ],
#        [-0.51118624],
#        [-0.2739134 ],
#        [-0.22633874]], dtype=float32), array([-1.007586], dtype=float32)]

# %% [markdown]
# # Увеличиваем нелинейность
# Применяем более сложную функцию активации – гиперболический тангенс

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(40, input_dim=1, activation='tanh'))
    model.add(Dense(1, input_dim=40, activation='linear'))
    
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# [array([[-0.07340864, -0.07798284,  0.07772817,  0.00801139, -3.106598  ,
#          0.07677249,  5.255477  , -0.07606095,  0.0764925 , -0.0773791 ,
#         -0.07482964,  0.1092169 ,  0.07561754, -0.07019879,  0.05971177,
#          0.08105808, -0.07633591,  0.07445474, -0.07834585, -0.07778662,
#          0.08004561, -4.267793  ,  0.07644123, -0.0765353 , -0.05854519,
#          3.2214305 , -0.0794747 , -0.07719823,  0.07695144, -0.0516345 ,
#          0.07686651, -0.07601928, -0.07759808, -0.06950513,  0.07522242,
#          0.07542187,  0.07968409, -0.07666973,  0.07739519,  0.07659949]],
#       dtype=float32), array([-1.66556984e-02, -2.43277363e-02,  2.22937632e-02,  1.74243539e-03,
#         4.17965412e+00,  2.02331711e-02,  1.26357450e+01, -1.89297628e-02,
#         1.96282789e-02, -2.25331653e-02, -1.76030770e-02, -1.47822261e-01,
#         1.91081166e-02, -1.54686235e-02,  1.25086978e-02,  7.75655638e-03,
#        -1.96924880e-02,  1.73100438e-02, -2.34111883e-02, -2.29803082e-02,
#         1.40618794e-02, -9.48966885e+00,  2.00158805e-02, -2.03241743e-02,
#        -1.24197565e-02, -5.86962318e+00, -1.73450615e-02, -2.12551914e-02,
#         2.14023180e-02, -1.08302711e-02,  2.03923304e-02, -1.88702960e-02,
#        -2.39020474e-02, -1.52418111e-02,  1.80385150e-02,  1.82373393e-02,
#         1.61599256e-02, -1.99734569e-02,  2.24903375e-02,  2.07041837e-02],
#       dtype=float32)]
# [array([[-0.08261476],
#        [-0.09399157],
#        [ 0.09298459],
#        [ 0.00744289],
#        [-1.8878423 ],
#        [ 0.09028804],
#        [ 4.2175345 ],
#        [-0.08844704],
#        [ 0.08953852],
#        [-0.09212795],
#        [-0.08559109],
#        [ 0.14937097],
#        [ 0.08747365],
#        [-0.07668753],
#        [ 0.06116911],
#        [ 0.09950069],
#        [-0.08918136],
#        [ 0.08477797],
#        [-0.09481447],
#        [-0.09324868],
#        [ 0.09783478],
#        [ 3.5093174 ],
#        [ 0.08947166],
#        [-0.08973598],
#        [-0.05966739],
#        [-1.8501924 ],
#        [-0.09684253],
#        [-0.09147755],
#        [ 0.09089162],
#        [-0.05126565],
#        [ 0.09053729],
#        [-0.0883445 ],
#        [-0.09290709],
#        [-0.07550766],
#        [ 0.0864786 ],
#        [ 0.08693511],
#        [ 0.09720961],
#        [-0.09000565],
#        [ 0.09216192],
#        [ 0.08994178]], dtype=float32), array([-0.6393946], dtype=float32)]

# %% [markdown]
# # Совершенствуем стартовую разметку
# Используем стартовую инициализацию весов glorot_normal, моделирующую усеченное равномерное распределение с центром в 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(40, input_dim=1, activation='tanh', bias_initializer='glorot_normal', kernel_initializer='glorot_normal'))
    model.add(Dense(1, input_dim=40, activation='linear', bias_initializer='glorot_normal', kernel_initializer='glorot_normal'))
    
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# [array([[-0.44653812, -0.4453195 , -0.4430169 ,  0.44437718,  0.44454512,
#          0.4629544 , -0.4451938 ,  0.44375747, -0.44286877,  0.49433234,
#         -0.44462097,  5.196431  , -0.44389135, -0.44613615,  1.6826346 ,
#          1.8823733 ,  4.5188265 , -0.44437766, -3.0002668 , -1.1426848 ,
#          0.3450758 , -0.43659887,  0.45556307,  0.46163878,  0.44534707,
#          0.6943736 ,  0.52461445, -0.44282407, -0.4403946 ,  0.9262353 ,
#          2.3659422 ,  1.8908093 ,  0.5270361 ,  3.1566327 ,  0.44502217,
#          1.5444894 ,  2.2786934 ,  0.46281737,  0.44718695, -0.02943957]],
#       dtype=float32), array([ 0.44254133,  0.40209216,  0.23970103, -0.2891977 , -0.3511447 ,
#        -0.6587617 ,  0.39721316, -0.34523252,  0.26950517, -0.8791003 ,
#         0.37201032, 10.654194  ,  0.35334423,  0.4307053 ,  0.12063041,
#        -1.062744  ,  4.7724333 ,  0.3153286 ,  6.2779107 , -0.9783715 ,
#        -0.01651017,  0.1742525 , -0.5854494 , -0.64702266, -0.40330017,
#        -1.7298342 , -1.0420384 ,  0.20979759,  0.28502247,  0.53551453,
#        -3.8194351 ,  2.6303566 , -1.0539985 ,  7.1799293 , -0.38900447,
#        -0.05095372,  0.53968394, -0.6580826 , -0.45899042,  0.8269789 ],
#       dtype=float32)]
# [array([[-0.73409647],
#        [-0.7064759 ],
#        [-0.58340293],
#        [ 0.62570596],
#        [ 0.6706235 ],
#        [ 0.86726916],
#        [-0.7028982 ],
#        [ 0.65981203],
#        [-0.6025389 ],
#        [ 0.9871142 ],
#        [-0.6839171 ],
#        [-5.550968  ],
#        [-0.66598475],
#        [-0.7262898 ],
#        [-1.2902994 ],
#        [-3.0878031 ],
#        [-3.5025635 ],
#        [-0.64471126],
#        [ 4.323179  ],
#        [-0.9686918 ],
#        [ 0.38190994],
#        [-0.5234563 ],
#        [ 0.8242162 ],
#        [ 0.85992545],
#        [ 0.70730406],
#        [ 1.4498215 ],
#        [ 1.0717251 ],
#        [-0.56379384],
#        [-0.59754264],
#        [ 0.66687864],
#        [-1.9694101 ],
#        [ 2.4502375 ],
#        [ 1.0781947 ],
#        [ 4.3646655 ],
#        [ 0.6971191 ],
#        [-1.2828357 ],
#        [-1.2547224 ],
#        [ 0.86474925],
#        [ 0.74485785],
#        [ 0.75784546]], dtype=float32), array([2.2793415], dtype=float32)]

# %% [markdown]
# Используем стартовую инициализацию весов he_normal, моделирующую усеченное гауссовское распределение с центром в 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(40, input_dim=1, activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))
    model.add(Dense(1, input_dim=40, activation='linear', bias_initializer='he_normal', kernel_initializer='he_normal'))
    
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# [array([[ 0.91728014,  1.495765  ,  1.0228872 ,  1.5614125 ,  1.8719454 ,
#         -0.8556459 , -1.4824255 , -1.5525529 ,  3.3160188 , -1.3031802 ,
#         -2.266401  ,  1.4318271 ,  1.3304663 , -2.472947  , -0.06564208,
#         -1.7932622 ,  1.0257046 , -1.976933  , -1.716814  , -1.4179218 ,
#         -1.9033238 ,  2.0909648 ,  4.4149575 , -0.73476446, -1.534924  ,
#          2.6780922 ,  1.9095379 , -2.8110964 ,  2.8874166 ,  0.713919  ,
#          1.0433224 , -1.2288225 ,  1.463775  , -0.9201406 ,  1.7306651 ,
#         -1.2162657 ,  4.513623  , -1.7243888 ,  1.7140499 ,  3.9984307 ]],
#       dtype=float32), array([ 5.1501771e-03,  6.2826478e-01,  3.8264731e-01, -5.4784495e-01,
#         1.2105507e+00,  1.5931152e-01,  7.1400797e-01, -6.9779623e-01,
#         3.5595858e+00,  1.6906528e+00,  9.9845642e-01, -4.1084371e+00,
#        -1.9497405e+00, -3.6214161e+00, -3.4226463e+00, -2.3467934e+00,
#         1.4764766e-01,  7.1999186e-01, -3.9780670e-01,  4.0653348e+00,
#         5.8820486e-02, -3.4165353e-01,  1.0619351e+01,  3.7811518e-02,
#         3.3682096e-01, -5.9541955e+00, -1.8792203e-01, -2.7422571e+00,
#        -3.4982502e+00, -6.6248216e-02,  5.2143788e-01,  4.3396094e-01,
#         1.4972453e+00,  2.4621398e+00,  3.0429524e-01, -7.1872306e-01,
#         9.3427200e+00,  1.2066172e+00, -2.6294222e-01,  2.7419865e+00],
#       dtype=float32)]
# [array([[-0.04818467],
#        [-0.71818876],
#        [ 0.61359906],
#        [ 0.1476081 ],
#        [-1.0942124 ],
#        [-0.01490476],
#        [-0.3008462 ],
#        [ 0.7910552 ],
#        [-2.9237235 ],
#        [ 1.1867099 ],
#        [ 0.61931604],
#        [ 2.9047687 ],
#        [-1.2767413 ],
#        [-2.8921018 ],
#        [-2.622037  ],
#        [-1.8162432 ],
#        [ 1.0202147 ],
#        [ 0.4840859 ],
#        [ 0.47918406],
#        [-2.8697088 ],
#        [ 0.01638745],
#        [-0.02855375],
#        [ 3.5797284 ],
#        [-0.03914993],
#        [-0.26287997],
#        [-3.5882032 ],
#        [ 0.01297905],
#        [ 2.2640154 ],
#        [ 2.2178986 ],
#        [ 0.17800267],
#        [ 0.50287884],
#        [-0.16975854],
#        [ 1.2408928 ],
#        [-1.6876559 ],
#        [-0.3243859 ],
#        [-1.0855198 ],
#        [-4.5874166 ],
#        [-0.8222868 ],
#        [-0.4069036 ],
#        [ 1.9552945 ]], dtype=float32), array([0.66604114], dtype=float32)]

# %% [markdown]
# # Рассмотрим поведение отдельных нейронов
# Видим, что каждый из нейронов (синие линии) настроен на моделирование нелинейности на определенном участке области определения функции

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(10, input_dim=1, activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))
    model.add(Dense(1, input_dim=10, activation='linear', bias_initializer='he_normal', kernel_initializer='he_normal'))
    
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# с помощью матрицы весов моделируем выход каждого отдельного нейрона перед суммацией
def tanh(x, i):
    w0 = model.layers[0].get_weights()
    w1 = model.layers[1].get_weights()
    
    return w1[0][i][0] * np.tanh(w0[0][0][i] * x + w0[1][i]) + w1[1][0]

# рисуем функцию и приближение
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)

# рисуем разложение
for i in range(0, 10, 1):
    plt.plot(x, tanh(x, i), color='blue',
         linewidth=1)

plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# [array([[ 1.4606844,  3.7755468,  2.4116976,  3.4165108, -1.919187 ,
#          5.088102 ,  3.1276994,  2.7443902, -2.5209956, -3.5162878]],
#       dtype=float32), array([ 0.585259  ,  7.910238  , -0.33519617,  2.2972617 ,  5.4801927 ,
#        12.204726  ,  3.3935554 , -5.9756308 ,  2.9249864 , -5.2203956 ],
#       dtype=float32)]
# [array([[-0.5435637 ],
#        [-4.339269  ],
#        [-0.28018433],
#        [ 1.7888019 ],
#        [-4.4785905 ],
#        [ 3.7643366 ],
#        [-3.2495863 ],
#        [-2.9556391 ],
#        [-1.8675293 ],
#        [-3.6505396 ]], dtype=float32), array([2.1130104], dtype=float32)]

# %% [markdown]
# # Интерполяция, но не экстраполяция
# Можно видеть, что функция воспроизводится адекватно только в "изученной" сетью области.
# За ее пределами результат как отдельных нейронов, так и сети в целом стремится к константе.

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(10, input_dim=1, activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))
    model.add(Dense(1, input_dim=10, activation='linear', bias_initializer='he_normal', kernel_initializer='he_normal'))
    
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)
plt.show()

# с помощью матрицы весом моделируем выход каждого отдельного нейрона перед суммацией
def tanh(x, i):
    w0 = model.layers[0].get_weights()
    w1 = model.layers[1].get_weights()
    
    return w1[0][i][0] * np.tanh(w0[0][0][i] * x + w0[1][i]) + w1[1][0]

# рисуем функцию и приближение
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)

# рисуем разложение
for i in range(0, 10, 1):
    plt.plot(x, tanh(x, i), color='blue',
         linewidth=1)

plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
        
# накидываем 2 тысячи точек от -6 до 6
x1 = np.linspace(-6, 6, 2000).reshape(-1, 1)

# вычисляем вектор значений функции
y1 = f(x1)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x1, y1, color='black', antialiased=True)
plt.plot(x1, model.predict(x1), color='magenta', linewidth=2, antialiased=True)

# рисуем разложение
for i in range(0, 10, 1):
    plt.plot(x1, tanh(x1, i), color='blue',
         linewidth=1)

plt.show()
# Out:
# 32/32 [==============================] - 0s 947us/step
# 32/32 [==============================] - 0s 1ms/step
# [array([[ 4.549513 ,  2.1012764,  3.1249983,  1.6987306, -2.4741197,
#          3.3304536,  4.067767 ,  5.164236 , -0.2726798, -2.3687732]],
#       dtype=float32), array([ 3.040192 , -6.012159 , -3.6880167,  2.4335105,  5.4711914,
#         5.0506806,  8.332016 , 12.539979 ,  1.0189509, -2.401226 ],
#       dtype=float32)]
# [array([[ 1.9655013 ],
#        [ 5.031827  ],
#        [ 1.8920652 ],
#        [ 0.45338756],
#        [ 2.8412912 ],
#        [ 3.6644492 ],
#        [-4.0742226 ],
#        [ 3.395035  ],
#        [ 2.3582406 ],
#        [ 4.1236134 ]], dtype=float32), array([0.9717679], dtype=float32)]
# 63/63 [==============================] - 0s 992us/step

# %% [markdown]
# # Усложним структуру сети
# Наращиваем число слоев, варьируем число нейронов в слое. Улучшение результата аппроксимации видно на глаз. Экстраполяция не улучшилась

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(12, input_dim=1, activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))
    model.add(Dense(12, input_dim=12, activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))    
    model.add(Dense(1, input_dim=12, activation='linear', bias_initializer='he_normal', kernel_initializer='he_normal'))
    
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 0)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)

plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
        
# накидываем тысячу точек от -6 до 6
x1 = np.linspace(-6, 6, 1000).reshape(-1, 1)

# вычисляем вектор значений функции
y1 = f(x1)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x1, y1, color='black', antialiased=True)
plt.plot(x1, model.predict(x1), color='magenta', linewidth=2, antialiased=True)

plt.show()
# Out:
# 32/32 [==============================] - 0s 989us/step
# [array([[ 1.6321931 ,  2.3531678 ,  1.8469071 ,  0.75394565, -0.8931953 ,
#          0.90629846,  3.0428784 , -2.2497797 , -1.0403125 ,  2.0158248 ,
#          0.7531182 , -1.6110175 ]], dtype=float32), array([-1.2114567 ,  1.4699249 ,  0.49608877,  0.13237205,  2.7178254 ,
#        -2.649938  ,  3.9348009 , -0.04249264,  1.2935253 ,  5.0500803 ,
#        -1.6950105 , -0.13934842], dtype=float32)]
# [array([[ 0.07733992,  0.40302438, -0.06813256, -0.03627468, -0.40418455,
#         -1.0789871 ,  1.2721459 ,  0.17625189,  0.02268178,  0.23730566,
#         -0.7896166 , -0.15194382],
#        [ 0.29986152, -0.14608718, -0.16575938, -0.514106  ,  0.03539029,
#         -0.43253177, -0.37116542, -0.3694622 , -0.19476679,  1.7230177 ,
#         -0.738741  ,  0.8062806 ],
#        [-0.55672187, -0.6909673 ,  0.3477988 , -0.22848648,  0.15897836,
#         -0.29019773, -0.24869475,  0.3674749 , -0.78669083,  0.4845813 ,
#         -0.69688296,  0.61772865],
#        [ 0.3733579 ,  0.1800856 ,  0.6416952 , -0.28291434,  0.63415796,
#         -0.23323594,  0.61995536,  0.3484852 , -0.181664  ,  0.92054296,
#          0.04268832, -0.5480647 ],
#        [-1.566539  ,  0.37598267, -0.35125974, -0.17935011,  0.56473744,
#         -0.27261418, -0.49399135, -0.26498842, -2.2092168 , -0.5162731 ,
#          0.65120995, -0.4068719 ],
#        [ 2.4024866 ,  0.37156475, -1.0362003 , -0.5260354 ,  0.7927254 ,
#          0.01357538,  0.11051916,  0.02348511,  0.96639854,  0.6592146 ,
#          0.02854462, -0.65612966],
#        [-0.03503454,  0.3276232 ,  1.0501122 , -0.51106995,  0.3708373 ,
#         -0.07998043,  0.10892128,  0.17297095,  2.7747    , -2.8399923 ,
#          0.3448486 , -0.35132882],
#        [ 0.26937526,  0.18209872, -0.11497027, -0.3764853 , -0.4316546 ,
#          0.02629633, -0.05151005,  0.20333661,  0.64385176,  0.31714833,
#          0.59502405, -0.31750748],
#        [-0.5097039 ,  0.658496  , -0.2088739 ,  0.3874511 , -0.32295835,
#          0.14029433, -0.6712588 , -0.9916958 , -1.4031768 , -0.4248328 ,
#          0.14522557, -0.23024878],
#        [-0.35286283,  1.293219  , -2.2208724 , -2.5656846 , -1.8569546 ,
#         -0.01694614,  0.18150145, -1.9390552 , -0.75808233,  4.280695  ,
#         -0.89279175, -3.2005723 ],
#        [ 1.1875788 , -0.19383281,  0.31731698, -0.01149746,  0.03641369,
#         -0.8434485 ,  0.7857654 ,  0.06637115,  0.6402785 ,  0.34111708,
#          0.20903713, -0.7141726 ],
#        [-0.5848885 ,  0.20966746,  0.01909203,  0.8887245 , -0.02526492,
#          0.188531  , -0.12441126, -0.6006771 ,  0.33439678, -0.06351573,
#          0.87135905,  0.13239132]], dtype=float32), array([-0.68856406,  0.10340899, -0.08913001, -0.35189173,  0.21706678,
#         0.2755635 ,  0.09140998,  0.78862786,  1.5293068 , -1.6548747 ,
#         0.49146047, -0.1664058 ], dtype=float32)]
# [array([[ 2.3469868 ],
#        [-0.6294669 ],
#        [ 1.3344649 ],
#        [ 0.79626614],
#        [ 1.0706142 ],
#        [-1.1710713 ],
#        [ 1.5306144 ],
#        [ 1.1840508 ],
#        [-2.647322  ],
#        [-3.9114609 ],
#        [-0.8914436 ],
#        [-3.552569  ]], dtype=float32), array([1.8843821], dtype=float32)]
# 32/32 [==============================] - 0s 1ms/step

# %% [markdown]
# # Анализируем точность в зависимости от длительности обучения и сложности сети
# Попробуем различное количество эпох обучения, начав с 10 и увеличивая их на 10 за попытку
# И затем - различное количество нейронов в скрытых слоях от 1 и будем наращивать до 50

# %%
import matplotlib.pyplot as plt
import numpy as np

# накидываем тысячу точек от -3 до 3
x = np.linspace(-3, 3, 1000).reshape(-1, 1)

# задаём линейную функцию, которую попробуем приблизить нашей нейронной сетью
def f(x):    
    return x * np.sin(x * 2 * np.pi) if x < 0 else -x * np.sin(x * np.pi) + np.exp(x / 2) - np.exp(0)

f = np.vectorize(f)

# вычисляем вектор значений функции
y = f(x)

# создаём модель нейросети, используя Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import SGD

def baseline_model():
    model = Sequential()
    model.add(Dense(12, input_dim=1, activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))
    model.add(Dense(12, input_dim=12, activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))   
    model.add(Dense(1, input_dim=12, activation='linear', bias_initializer='he_normal', kernel_initializer='he_normal'))
    
    sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(loss='mean_squared_error', optimizer=sgd)
    return model

# тренируем сеть
model = baseline_model()
model.summary()
# model.fit(x, y, nb_epoch=100, verbose = 0)
model.fit(x, y, epochs=400, verbose = 2)

# отрисовываем результат приближения нейросетью поверх исходной функции
plt.scatter(x, y, color='black', antialiased=True)
plt.plot(x, model.predict(x), color='magenta', linewidth=2, antialiased=True)

plt.show()

# выводим веса на экран
for layer in model.layers:
    weights = layer.get_weights()
    print(weights)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_38 (Dense)            (None, 12)                24
#
#  dense_39 (Dense)            (None, 12)                156
#
#  dense_40 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 193 (772.00 Byte)
# Trainable params: 193 (772.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/400
# 32/32 - 0s - loss: 1.2357 - 359ms/epoch - 11ms/step
# Epoch 2/400
# 32/32 - 0s - loss: 1.1257 - 46ms/epoch - 1ms/step
# Epoch 3/400
# 32/32 - 0s - loss: 1.0842 - 44ms/epoch - 1ms/step
# Epoch 4/400
# 32/32 - 0s - loss: 1.0958 - 50ms/epoch - 2ms/step
# Epoch 5/400
# 32/32 - 0s - loss: 1.0581 - 49ms/epoch - 2ms/step
# Epoch 6/400
# 32/32 - 0s - loss: 1.0386 - 51ms/epoch - 2ms/step
# Epoch 7/400
# 32/32 - 0s - loss: 1.0284 - 50ms/epoch - 2ms/step
# Epoch 8/400
# 32/32 - 0s - loss: 0.9944 - 47ms/epoch - 1ms/step
# Epoch 9/400
# 32/32 - 0s - loss: 0.9508 - 43ms/epoch - 1ms/step
# Epoch 10/400
# 32/32 - 0s - loss: 0.9385 - 55ms/epoch - 2ms/step
# Epoch 11/400
# 32/32 - 0s - loss: 0.8983 - 53ms/epoch - 2ms/step
# Epoch 12/400
# 32/32 - 0s - loss: 0.8927 - 52ms/epoch - 2ms/step
# Epoch 13/400
# 32/32 - 0s - loss: 0.8709 - 51ms/epoch - 2ms/step
# Epoch 14/400
# 32/32 - 0s - loss: 0.8746 - 49ms/epoch - 2ms/step
# Epoch 15/400
# 32/32 - 0s - loss: 0.8570 - 48ms/epoch - 2ms/step
# Epoch 16/400
# 32/32 - 0s - loss: 0.8625 - 50ms/epoch - 2ms/step
# Epoch 17/400
# 32/32 - 0s - loss: 0.8636 - 44ms/epoch - 1ms/step
# Epoch 18/400
# 32/32 - 0s - loss: 0.8530 - 44ms/epoch - 1ms/step
# Epoch 19/400
# 32/32 - 0s - loss: 0.8664 - 44ms/epoch - 1ms/step
# Epoch 20/400
# 32/32 - 0s - loss: 0.8244 - 41ms/epoch - 1ms/step
# Epoch 21/400
# 32/32 - 0s - loss: 0.8384 - 48ms/epoch - 2ms/step
# Epoch 22/400
# 32/32 - 0s - loss: 0.8182 - 45ms/epoch - 1ms/step
# Epoch 23/400
# 32/32 - 0s - loss: 0.8051 - 54ms/epoch - 2ms/step
# Epoch 24/400
# 32/32 - 0s - loss: 0.8062 - 41ms/epoch - 1ms/step
# Epoch 25/400
# 32/32 - 0s - loss: 0.8194 - 35ms/epoch - 1ms/step
# Epoch 26/400
# 32/32 - 0s - loss: 0.8021 - 53ms/epoch - 2ms/step
# Epoch 27/400
# 32/32 - 0s - loss: 0.8196 - 42ms/epoch - 1ms/step
# Epoch 28/400
# 32/32 - 0s - loss: 0.7890 - 35ms/epoch - 1ms/step
# Epoch 29/400
# 32/32 - 0s - loss: 0.7676 - 51ms/epoch - 2ms/step
# Epoch 30/400
# 32/32 - 0s - loss: 0.7683 - 40ms/epoch - 1ms/step
# Epoch 31/400
# 32/32 - 0s - loss: 0.7748 - 38ms/epoch - 1ms/step
# Epoch 32/400
# 32/32 - 0s - loss: 0.7471 - 47ms/epoch - 1ms/step
# Epoch 33/400
# 32/32 - 0s - loss: 0.7319 - 43ms/epoch - 1ms/step
# Epoch 34/400
# 32/32 - 0s - loss: 0.7143 - 41ms/epoch - 1ms/step
# Epoch 35/400
# 32/32 - 0s - loss: 0.7277 - 39ms/epoch - 1ms/step
# Epoch 36/400
# 32/32 - 0s - loss: 0.7148 - 45ms/epoch - 1ms/step
# Epoch 37/400
# 32/32 - 0s - loss: 0.6967 - 44ms/epoch - 1ms/step
# Epoch 38/400
# 32/32 - 0s - loss: 0.6496 - 51ms/epoch - 2ms/step
# Epoch 39/400
# 32/32 - 0s - loss: 0.6491 - 56ms/epoch - 2ms/step
# Epoch 40/400
# 32/32 - 0s - loss: 0.6451 - 40ms/epoch - 1ms/step
# Epoch 41/400
# 32/32 - 0s - loss: 0.6009 - 38ms/epoch - 1ms/step
# Epoch 42/400
# 32/32 - 0s - loss: 0.5937 - 37ms/epoch - 1ms/step
# Epoch 43/400
# 32/32 - 0s - loss: 0.5728 - 54ms/epoch - 2ms/step
# Epoch 44/400
# 32/32 - 0s - loss: 0.5368 - 43ms/epoch - 1ms/step
# Epoch 45/400
# 32/32 - 0s - loss: 0.5013 - 48ms/epoch - 2ms/step
# Epoch 46/400
# 32/32 - 0s - loss: 0.4820 - 49ms/epoch - 2ms/step
# Epoch 47/400
# 32/32 - 0s - loss: 0.4702 - 39ms/epoch - 1ms/step
# Epoch 48/400
# 32/32 - 0s - loss: 0.4470 - 35ms/epoch - 1ms/step
# Epoch 49/400
# 32/32 - 0s - loss: 0.4163 - 34ms/epoch - 1ms/step
# Epoch 50/400
# 32/32 - 0s - loss: 0.4131 - 33ms/epoch - 1ms/step
# Epoch 51/400
# 32/32 - 0s - loss: 0.3875 - 41ms/epoch - 1ms/step
# Epoch 52/400
# 32/32 - 0s - loss: 0.3740 - 36ms/epoch - 1ms/step
# Epoch 53/400
# 32/32 - 0s - loss: 0.3567 - 37ms/epoch - 1ms/step
# Epoch 54/400
# 32/32 - 0s - loss: 0.3470 - 40ms/epoch - 1ms/step
# Epoch 55/400
# 32/32 - 0s - loss: 0.3271 - 67ms/epoch - 2ms/step
# Epoch 56/400
# 32/32 - 0s - loss: 0.3191 - 56ms/epoch - 2ms/step
# Epoch 57/400
# 32/32 - 0s - loss: 0.3112 - 37ms/epoch - 1ms/step
# Epoch 58/400
# 32/32 - 0s - loss: 0.3039 - 37ms/epoch - 1ms/step
# Epoch 59/400
# 32/32 - 0s - loss: 0.2924 - 44ms/epoch - 1ms/step
# Epoch 60/400
# 32/32 - 0s - loss: 0.2933 - 41ms/epoch - 1ms/step
# Epoch 61/400
# 32/32 - 0s - loss: 0.2832 - 39ms/epoch - 1ms/step
# Epoch 62/400
# 32/32 - 0s - loss: 0.2697 - 49ms/epoch - 2ms/step
# Epoch 63/400
# 32/32 - 0s - loss: 0.2715 - 42ms/epoch - 1ms/step
# Epoch 64/400
# 32/32 - 0s - loss: 0.2639 - 40ms/epoch - 1ms/step
# Epoch 65/400
# 32/32 - 0s - loss: 0.2483 - 41ms/epoch - 1ms/step
# Epoch 66/400
# 32/32 - 0s - loss: 0.2458 - 45ms/epoch - 1ms/step
# Epoch 67/400
# 32/32 - 0s - loss: 0.2369 - 70ms/epoch - 2ms/step
# Epoch 68/400
# 32/32 - 0s - loss: 0.2307 - 46ms/epoch - 1ms/step
# Epoch 69/400
# 32/32 - 0s - loss: 0.2158 - 36ms/epoch - 1ms/step
# Epoch 70/400
# 32/32 - 0s - loss: 0.2018 - 35ms/epoch - 1ms/step
# Epoch 71/400
# 32/32 - 0s - loss: 0.1997 - 35ms/epoch - 1ms/step
# Epoch 72/400
# 32/32 - 0s - loss: 0.1787 - 44ms/epoch - 1ms/step
# Epoch 73/400
# 32/32 - 0s - loss: 0.1684 - 34ms/epoch - 1ms/step
# Epoch 74/400
# 32/32 - 0s - loss: 0.1548 - 37ms/epoch - 1ms/step
# Epoch 75/400
# 32/32 - 0s - loss: 0.1402 - 33ms/epoch - 1ms/step
# Epoch 76/400
# 32/32 - 0s - loss: 0.1319 - 44ms/epoch - 1ms/step
# Epoch 77/400
# 32/32 - 0s - loss: 0.1244 - 41ms/epoch - 1ms/step
# Epoch 78/400
# 32/32 - 0s - loss: 0.1212 - 41ms/epoch - 1ms/step
# Epoch 79/400
# 32/32 - 0s - loss: 0.1100 - 48ms/epoch - 2ms/step
# Epoch 80/400
# 32/32 - 0s - loss: 0.1033 - 46ms/epoch - 1ms/step
# Epoch 81/400
# 32/32 - 0s - loss: 0.0962 - 49ms/epoch - 2ms/step
# Epoch 82/400
# 32/32 - 0s - loss: 0.0941 - 47ms/epoch - 1ms/step
# Epoch 83/400
# 32/32 - 0s - loss: 0.0925 - 42ms/epoch - 1ms/step
# Epoch 84/400
# 32/32 - 0s - loss: 0.0897 - 40ms/epoch - 1ms/step
# Epoch 85/400
# 32/32 - 0s - loss: 0.0825 - 41ms/epoch - 1ms/step
# Epoch 86/400
# 32/32 - 0s - loss: 0.0829 - 39ms/epoch - 1ms/step
# Epoch 87/400
# 32/32 - 0s - loss: 0.0858 - 40ms/epoch - 1ms/step
# Epoch 88/400
# 32/32 - 0s - loss: 0.0736 - 42ms/epoch - 1ms/step
# Epoch 89/400
# 32/32 - 0s - loss: 0.0699 - 41ms/epoch - 1ms/step
# Epoch 90/400
# 32/32 - 0s - loss: 0.0673 - 38ms/epoch - 1ms/step
# Epoch 91/400
# 32/32 - 0s - loss: 0.0697 - 41ms/epoch - 1ms/step
# Epoch 92/400
# 32/32 - 0s - loss: 0.0869 - 43ms/epoch - 1ms/step
# Epoch 93/400
# 32/32 - 0s - loss: 0.0619 - 46ms/epoch - 1ms/step
# Epoch 94/400
# 32/32 - 0s - loss: 0.0639 - 44ms/epoch - 1ms/step
# Epoch 95/400
# 32/32 - 0s - loss: 0.0632 - 44ms/epoch - 1ms/step
# Epoch 96/400
# 32/32 - 0s - loss: 0.0641 - 42ms/epoch - 1ms/step
# Epoch 97/400
# 32/32 - 0s - loss: 0.0607 - 46ms/epoch - 1ms/step
# Epoch 98/400
# 32/32 - 0s - loss: 0.0613 - 40ms/epoch - 1ms/step
# Epoch 99/400
# 32/32 - 0s - loss: 0.0600 - 44ms/epoch - 1ms/step
# Epoch 100/400
# 32/32 - 0s - loss: 0.0528 - 38ms/epoch - 1ms/step
# Epoch 101/400
# 32/32 - 0s - loss: 0.0655 - 43ms/epoch - 1ms/step
# Epoch 102/400
# 32/32 - 0s - loss: 0.0531 - 35ms/epoch - 1ms/step
# Epoch 103/400
# 32/32 - 0s - loss: 0.0544 - 44ms/epoch - 1ms/step
# Epoch 104/400
# 32/32 - 0s - loss: 0.0512 - 41ms/epoch - 1ms/step
# Epoch 105/400
# 32/32 - 0s - loss: 0.0584 - 45ms/epoch - 1ms/step
# Epoch 106/400
# 32/32 - 0s - loss: 0.0554 - 33ms/epoch - 1ms/step
# Epoch 107/400
# 32/32 - 0s - loss: 0.0591 - 43ms/epoch - 1ms/step
# Epoch 108/400
# 32/32 - 0s - loss: 0.0561 - 38ms/epoch - 1ms/step
# Epoch 109/400
# 32/32 - 0s - loss: 0.0522 - 42ms/epoch - 1ms/step
# Epoch 110/400
# 32/32 - 0s - loss: 0.0517 - 43ms/epoch - 1ms/step
# Epoch 111/400
# 32/32 - 0s - loss: 0.0502 - 40ms/epoch - 1ms/step
# Epoch 112/400
# 32/32 - 0s - loss: 0.0512 - 46ms/epoch - 1ms/step
# Epoch 113/400
# 32/32 - 0s - loss: 0.0517 - 43ms/epoch - 1ms/step
# Epoch 114/400
# 32/32 - 0s - loss: 0.0491 - 48ms/epoch - 2ms/step
# Epoch 115/400
# 32/32 - 0s - loss: 0.0578 - 41ms/epoch - 1ms/step
# Epoch 116/400
# 32/32 - 0s - loss: 0.0513 - 47ms/epoch - 1ms/step
# Epoch 117/400
# 32/32 - 0s - loss: 0.0479 - 33ms/epoch - 1ms/step
# Epoch 118/400
# 32/32 - 0s - loss: 0.0489 - 41ms/epoch - 1ms/step
# Epoch 119/400
# 32/32 - 0s - loss: 0.0495 - 47ms/epoch - 1ms/step
# Epoch 120/400
# 32/32 - 0s - loss: 0.0517 - 33ms/epoch - 1ms/step
# Epoch 121/400
# 32/32 - 0s - loss: 0.0552 - 36ms/epoch - 1ms/step
# Epoch 122/400
# 32/32 - 0s - loss: 0.0505 - 44ms/epoch - 1ms/step
# Epoch 123/400
# 32/32 - 0s - loss: 0.0493 - 40ms/epoch - 1ms/step
# Epoch 124/400
# 32/32 - 0s - loss: 0.0515 - 40ms/epoch - 1ms/step
# Epoch 125/400
# 32/32 - 0s - loss: 0.0491 - 40ms/epoch - 1ms/step
# Epoch 126/400
# 32/32 - 0s - loss: 0.0458 - 38ms/epoch - 1ms/step
# Epoch 127/400
# 32/32 - 0s - loss: 0.0450 - 38ms/epoch - 1ms/step
# Epoch 128/400
# 32/32 - 0s - loss: 0.0447 - 39ms/epoch - 1ms/step
# Epoch 129/400
# 32/32 - 0s - loss: 0.0463 - 43ms/epoch - 1ms/step
# Epoch 130/400
# 32/32 - 0s - loss: 0.0506 - 40ms/epoch - 1ms/step
# Epoch 131/400
# 32/32 - 0s - loss: 0.0461 - 47ms/epoch - 1ms/step
# Epoch 132/400
# 32/32 - 0s - loss: 0.0492 - 41ms/epoch - 1ms/step
# Epoch 133/400
# 32/32 - 0s - loss: 0.0464 - 39ms/epoch - 1ms/step
# Epoch 134/400
# 32/32 - 0s - loss: 0.0469 - 45ms/epoch - 1ms/step
# Epoch 135/400
# 32/32 - 0s - loss: 0.0471 - 47ms/epoch - 1ms/step
# Epoch 136/400
# 32/32 - 0s - loss: 0.0759 - 39ms/epoch - 1ms/step
# Epoch 137/400
# 32/32 - 0s - loss: 0.0444 - 46ms/epoch - 1ms/step
# Epoch 138/400
# 32/32 - 0s - loss: 0.0472 - 35ms/epoch - 1ms/step
# Epoch 139/400
# 32/32 - 0s - loss: 0.0557 - 66ms/epoch - 2ms/step
# Epoch 140/400
# 32/32 - 0s - loss: 0.0436 - 42ms/epoch - 1ms/step
# Epoch 141/400
# 32/32 - 0s - loss: 0.0445 - 37ms/epoch - 1ms/step
# Epoch 142/400
# 32/32 - 0s - loss: 0.0744 - 36ms/epoch - 1ms/step
# Epoch 143/400
# 32/32 - 0s - loss: 0.0973 - 33ms/epoch - 1ms/step
# Epoch 144/400
# 32/32 - 0s - loss: 0.0415 - 36ms/epoch - 1ms/step
# Epoch 145/400
# 32/32 - 0s - loss: 0.0395 - 32ms/epoch - 987us/step
# Epoch 146/400
# 32/32 - 0s - loss: 0.0418 - 49ms/epoch - 2ms/step
# Epoch 147/400
# 32/32 - 0s - loss: 0.0418 - 33ms/epoch - 1ms/step
# Epoch 148/400
# 32/32 - 0s - loss: 0.0390 - 47ms/epoch - 1ms/step
# Epoch 149/400
# 32/32 - 0s - loss: 0.0423 - 32ms/epoch - 996us/step
# Epoch 150/400
# 32/32 - 0s - loss: 0.0453 - 48ms/epoch - 1ms/step
# Epoch 151/400
# 32/32 - 0s - loss: 0.0468 - 35ms/epoch - 1ms/step
# Epoch 152/400
# 32/32 - 0s - loss: 0.0385 - 47ms/epoch - 1ms/step
# Epoch 153/400
# 32/32 - 0s - loss: 0.0461 - 43ms/epoch - 1ms/step
# Epoch 154/400
# 32/32 - 0s - loss: 0.0427 - 45ms/epoch - 1ms/step
# Epoch 155/400
# 32/32 - 0s - loss: 0.0416 - 44ms/epoch - 1ms/step
# Epoch 156/400
# 32/32 - 0s - loss: 0.0391 - 43ms/epoch - 1ms/step
# Epoch 157/400
# 32/32 - 0s - loss: 0.0404 - 34ms/epoch - 1ms/step
# Epoch 158/400
# 32/32 - 0s - loss: 0.0409 - 45ms/epoch - 1ms/step
# Epoch 159/400
# 32/32 - 0s - loss: 0.0405 - 31ms/epoch - 969us/step
# Epoch 160/400
# 32/32 - 0s - loss: 0.0336 - 46ms/epoch - 1ms/step
# Epoch 161/400
# 32/32 - 0s - loss: 0.0384 - 35ms/epoch - 1ms/step
# Epoch 162/400
# 32/32 - 0s - loss: 0.0351 - 42ms/epoch - 1ms/step
# Epoch 163/400
# 32/32 - 0s - loss: 0.0354 - 41ms/epoch - 1ms/step
# Epoch 164/400
# 32/32 - 0s - loss: 0.0313 - 34ms/epoch - 1ms/step
# Epoch 165/400
# 32/32 - 0s - loss: 0.0370 - 43ms/epoch - 1ms/step
# Epoch 166/400
# 32/32 - 0s - loss: 0.0331 - 39ms/epoch - 1ms/step
# Epoch 167/400
# 32/32 - 0s - loss: 0.0367 - 40ms/epoch - 1ms/step
# Epoch 168/400
# 32/32 - 0s - loss: 0.0322 - 47ms/epoch - 1ms/step
# Epoch 169/400
# 32/32 - 0s - loss: 0.0284 - 38ms/epoch - 1ms/step
# Epoch 170/400
# 32/32 - 0s - loss: 0.0464 - 46ms/epoch - 1ms/step
# Epoch 171/400
# 32/32 - 0s - loss: 0.0451 - 37ms/epoch - 1ms/step
# Epoch 172/400
# 32/32 - 0s - loss: 0.0322 - 43ms/epoch - 1ms/step
# Epoch 173/400
# 32/32 - 0s - loss: 0.0280 - 43ms/epoch - 1ms/step
# Epoch 174/400
# 32/32 - 0s - loss: 0.0269 - 37ms/epoch - 1ms/step
# Epoch 175/400
# 32/32 - 0s - loss: 0.0300 - 46ms/epoch - 1ms/step
# Epoch 176/400
# 32/32 - 0s - loss: 0.0327 - 32ms/epoch - 1ms/step
# Epoch 177/400
# 32/32 - 0s - loss: 0.0357 - 46ms/epoch - 1ms/step
# Epoch 178/400
# 32/32 - 0s - loss: 0.0247 - 36ms/epoch - 1ms/step
# Epoch 179/400
# 32/32 - 0s - loss: 0.0245 - 33ms/epoch - 1ms/step
# Epoch 180/400
# 32/32 - 0s - loss: 0.0281 - 36ms/epoch - 1ms/step
# Epoch 181/400
# 32/32 - 0s - loss: 0.0215 - 41ms/epoch - 1ms/step
# Epoch 182/400
# 32/32 - 0s - loss: 0.0259 - 37ms/epoch - 1ms/step
# Epoch 183/400
# 32/32 - 0s - loss: 0.0417 - 43ms/epoch - 1ms/step
# Epoch 184/400
# 32/32 - 0s - loss: 0.0205 - 33ms/epoch - 1ms/step
# Epoch 185/400
# 32/32 - 0s - loss: 0.0269 - 47ms/epoch - 1ms/step
# Epoch 186/400
# 32/32 - 0s - loss: 0.0210 - 35ms/epoch - 1ms/step
# Epoch 187/400
# 32/32 - 0s - loss: 0.0175 - 45ms/epoch - 1ms/step
# Epoch 188/400
# 32/32 - 0s - loss: 0.0274 - 39ms/epoch - 1ms/step
# Epoch 189/400
# 32/32 - 0s - loss: 0.0216 - 41ms/epoch - 1ms/step
# Epoch 190/400
# 32/32 - 0s - loss: 0.0181 - 44ms/epoch - 1ms/step
# Epoch 191/400
# 32/32 - 0s - loss: 0.0182 - 46ms/epoch - 1ms/step
# Epoch 192/400
# 32/32 - 0s - loss: 0.0168 - 40ms/epoch - 1ms/step
# Epoch 193/400
# 32/32 - 0s - loss: 0.0150 - 39ms/epoch - 1ms/step
# Epoch 194/400
# 32/32 - 0s - loss: 0.0147 - 43ms/epoch - 1ms/step
# Epoch 195/400
# 32/32 - 0s - loss: 0.0141 - 37ms/epoch - 1ms/step
# Epoch 196/400
# 32/32 - 0s - loss: 0.0169 - 42ms/epoch - 1ms/step
# Epoch 197/400
# 32/32 - 0s - loss: 0.0174 - 36ms/epoch - 1ms/step
# Epoch 198/400
# 32/32 - 0s - loss: 0.0163 - 44ms/epoch - 1ms/step
# Epoch 199/400
# 32/32 - 0s - loss: 0.0175 - 35ms/epoch - 1ms/step
# Epoch 200/400
# 32/32 - 0s - loss: 0.0212 - 41ms/epoch - 1ms/step
# Epoch 201/400
# 32/32 - 0s - loss: 0.0144 - 39ms/epoch - 1ms/step
# Epoch 202/400
# 32/32 - 0s - loss: 0.0177 - 45ms/epoch - 1ms/step
# Epoch 203/400
# 32/32 - 0s - loss: 0.0145 - 38ms/epoch - 1ms/step
# Epoch 204/400
# 32/32 - 0s - loss: 0.0132 - 39ms/epoch - 1ms/step
# Epoch 205/400
# 32/32 - 0s - loss: 0.0119 - 50ms/epoch - 2ms/step
# Epoch 206/400
# 32/32 - 0s - loss: 0.0178 - 53ms/epoch - 2ms/step
# Epoch 207/400
# 32/32 - 0s - loss: 0.0133 - 41ms/epoch - 1ms/step
# Epoch 208/400
# 32/32 - 0s - loss: 0.0115 - 37ms/epoch - 1ms/step
# Epoch 209/400
# 32/32 - 0s - loss: 0.0116 - 44ms/epoch - 1ms/step
# Epoch 210/400
# 32/32 - 0s - loss: 0.0127 - 39ms/epoch - 1ms/step
# Epoch 211/400
# 32/32 - 0s - loss: 0.0104 - 41ms/epoch - 1ms/step
# Epoch 212/400
# 32/32 - 0s - loss: 0.0227 - 36ms/epoch - 1ms/step
# Epoch 213/400
# 32/32 - 0s - loss: 0.0155 - 43ms/epoch - 1ms/step
# Epoch 214/400
# 32/32 - 0s - loss: 0.0104 - 37ms/epoch - 1ms/step
# Epoch 215/400
# 32/32 - 0s - loss: 0.0200 - 41ms/epoch - 1ms/step
# Epoch 216/400
# 32/32 - 0s - loss: 0.0134 - 40ms/epoch - 1ms/step
# Epoch 217/400
# 32/32 - 0s - loss: 0.0124 - 43ms/epoch - 1ms/step
# Epoch 218/400
# 32/32 - 0s - loss: 0.0088 - 35ms/epoch - 1ms/step
# Epoch 219/400
# 32/32 - 0s - loss: 0.0181 - 43ms/epoch - 1ms/step
# Epoch 220/400
# 32/32 - 0s - loss: 0.0149 - 35ms/epoch - 1ms/step
# Epoch 221/400
# 32/32 - 0s - loss: 0.0087 - 45ms/epoch - 1ms/step
# Epoch 222/400
# 32/32 - 0s - loss: 0.0078 - 33ms/epoch - 1ms/step
# Epoch 223/400
# 32/32 - 0s - loss: 0.0088 - 48ms/epoch - 2ms/step
# Epoch 224/400
# 32/32 - 0s - loss: 0.0148 - 33ms/epoch - 1ms/step
# Epoch 225/400
# 32/32 - 0s - loss: 0.0098 - 50ms/epoch - 2ms/step
# Epoch 226/400
# 32/32 - 0s - loss: 0.0152 - 34ms/epoch - 1ms/step
# Epoch 227/400
# 32/32 - 0s - loss: 0.0105 - 46ms/epoch - 1ms/step
# Epoch 228/400
# 32/32 - 0s - loss: 0.0073 - 35ms/epoch - 1ms/step
# Epoch 229/400
# 32/32 - 0s - loss: 0.0188 - 46ms/epoch - 1ms/step
# Epoch 230/400
# 32/32 - 0s - loss: 0.0088 - 41ms/epoch - 1ms/step
# Epoch 231/400
# 32/32 - 0s - loss: 0.0130 - 39ms/epoch - 1ms/step
# Epoch 232/400
# 32/32 - 0s - loss: 0.0083 - 45ms/epoch - 1ms/step
# Epoch 233/400
# 32/32 - 0s - loss: 0.0082 - 37ms/epoch - 1ms/step
# Epoch 234/400
# 32/32 - 0s - loss: 0.0099 - 42ms/epoch - 1ms/step
# Epoch 235/400
# 32/32 - 0s - loss: 0.0108 - 41ms/epoch - 1ms/step
# Epoch 236/400
# 32/32 - 0s - loss: 0.0059 - 41ms/epoch - 1ms/step
# Epoch 237/400
# 32/32 - 0s - loss: 0.0060 - 40ms/epoch - 1ms/step
# Epoch 238/400
# 32/32 - 0s - loss: 0.0055 - 42ms/epoch - 1ms/step
# Epoch 239/400
# 32/32 - 0s - loss: 0.0072 - 40ms/epoch - 1ms/step
# Epoch 240/400
# 32/32 - 0s - loss: 0.0071 - 44ms/epoch - 1ms/step
# Epoch 241/400
# 32/32 - 0s - loss: 0.0066 - 45ms/epoch - 1ms/step
# Epoch 242/400
# 32/32 - 0s - loss: 0.0052 - 36ms/epoch - 1ms/step
# Epoch 243/400
# 32/32 - 0s - loss: 0.0154 - 44ms/epoch - 1ms/step
# Epoch 244/400
# 32/32 - 0s - loss: 0.0062 - 38ms/epoch - 1ms/step
# Epoch 245/400
# 32/32 - 0s - loss: 0.0184 - 45ms/epoch - 1ms/step
# Epoch 246/400
# 32/32 - 0s - loss: 0.0230 - 39ms/epoch - 1ms/step
# Epoch 247/400
# 32/32 - 0s - loss: 0.0047 - 41ms/epoch - 1ms/step
# Epoch 248/400
# 32/32 - 0s - loss: 0.0064 - 45ms/epoch - 1ms/step
# Epoch 249/400
# 32/32 - 0s - loss: 0.0059 - 39ms/epoch - 1ms/step
# Epoch 250/400
# 32/32 - 0s - loss: 0.0083 - 40ms/epoch - 1ms/step
# Epoch 251/400
# 32/32 - 0s - loss: 0.0082 - 41ms/epoch - 1ms/step
# Epoch 252/400
# 32/32 - 0s - loss: 0.0076 - 39ms/epoch - 1ms/step
# Epoch 253/400
# 32/32 - 0s - loss: 0.0050 - 39ms/epoch - 1ms/step
# Epoch 254/400
# 32/32 - 0s - loss: 0.0056 - 41ms/epoch - 1ms/step
# Epoch 255/400
# 32/32 - 0s - loss: 0.0045 - 40ms/epoch - 1ms/step
# Epoch 256/400
# 32/32 - 0s - loss: 0.0135 - 47ms/epoch - 1ms/step
# Epoch 257/400
# 32/32 - 0s - loss: 0.0067 - 34ms/epoch - 1ms/step
# Epoch 258/400
# 32/32 - 0s - loss: 0.0044 - 45ms/epoch - 1ms/step
# Epoch 259/400
# 32/32 - 0s - loss: 0.0045 - 35ms/epoch - 1ms/step
# Epoch 260/400
# 32/32 - 0s - loss: 0.0074 - 45ms/epoch - 1ms/step
# Epoch 261/400
# 32/32 - 0s - loss: 0.0045 - 35ms/epoch - 1ms/step
# Epoch 262/400
# 32/32 - 0s - loss: 0.0350 - 49ms/epoch - 2ms/step
# Epoch 263/400
# 32/32 - 0s - loss: 0.0157 - 35ms/epoch - 1ms/step
# Epoch 264/400
# 32/32 - 0s - loss: 0.0053 - 46ms/epoch - 1ms/step
# Epoch 265/400
# 32/32 - 0s - loss: 0.0071 - 43ms/epoch - 1ms/step
# Epoch 266/400
# 32/32 - 0s - loss: 0.0045 - 44ms/epoch - 1ms/step
# Epoch 267/400
# 32/32 - 0s - loss: 0.0036 - 50ms/epoch - 2ms/step
# Epoch 268/400
# 32/32 - 0s - loss: 0.0056 - 35ms/epoch - 1ms/step
# Epoch 269/400
# 32/32 - 0s - loss: 0.0077 - 46ms/epoch - 1ms/step
# Epoch 270/400
# 32/32 - 0s - loss: 0.0316 - 37ms/epoch - 1ms/step
# Epoch 271/400
# 32/32 - 0s - loss: 0.0175 - 47ms/epoch - 1ms/step
# Epoch 272/400
# 32/32 - 0s - loss: 0.0044 - 37ms/epoch - 1ms/step
# Epoch 273/400
# 32/32 - 0s - loss: 0.0054 - 45ms/epoch - 1ms/step
# Epoch 274/400
# 32/32 - 0s - loss: 0.0042 - 36ms/epoch - 1ms/step
# Epoch 275/400
# 32/32 - 0s - loss: 0.0042 - 40ms/epoch - 1ms/step
# Epoch 276/400
# 32/32 - 0s - loss: 0.0046 - 38ms/epoch - 1ms/step
# Epoch 277/400
# 32/32 - 0s - loss: 0.0035 - 41ms/epoch - 1ms/step
# Epoch 278/400
# 32/32 - 0s - loss: 0.0048 - 40ms/epoch - 1ms/step
# Epoch 279/400
# 32/32 - 0s - loss: 0.0049 - 44ms/epoch - 1ms/step
# Epoch 280/400
# 32/32 - 0s - loss: 0.0045 - 37ms/epoch - 1ms/step
# Epoch 281/400
# 32/32 - 0s - loss: 0.0043 - 45ms/epoch - 1ms/step
# Epoch 282/400
# 32/32 - 0s - loss: 0.0114 - 35ms/epoch - 1ms/step
# Epoch 283/400
# 32/32 - 0s - loss: 0.0039 - 48ms/epoch - 1ms/step
# Epoch 284/400
# 32/32 - 0s - loss: 0.0078 - 38ms/epoch - 1ms/step
# Epoch 285/400
# 32/32 - 0s - loss: 0.0037 - 43ms/epoch - 1ms/step
# Epoch 286/400
# 32/32 - 0s - loss: 0.0040 - 50ms/epoch - 2ms/step
# Epoch 287/400
# 32/32 - 0s - loss: 0.0080 - 35ms/epoch - 1ms/step
# Epoch 288/400
# 32/32 - 0s - loss: 0.0040 - 46ms/epoch - 1ms/step
# Epoch 289/400
# 32/32 - 0s - loss: 0.0027 - 44ms/epoch - 1ms/step
# Epoch 290/400
# 32/32 - 0s - loss: 0.0059 - 35ms/epoch - 1ms/step
# Epoch 291/400
# 32/32 - 0s - loss: 0.0034 - 42ms/epoch - 1ms/step
# Epoch 292/400
# 32/32 - 0s - loss: 0.0038 - 37ms/epoch - 1ms/step
# Epoch 293/400
# 32/32 - 0s - loss: 0.0054 - 43ms/epoch - 1ms/step
# Epoch 294/400
# 32/32 - 0s - loss: 0.0064 - 40ms/epoch - 1ms/step
# Epoch 295/400
# 32/32 - 0s - loss: 0.0045 - 43ms/epoch - 1ms/step
# Epoch 296/400
# 32/32 - 0s - loss: 0.0032 - 42ms/epoch - 1ms/step
# Epoch 297/400
# 32/32 - 0s - loss: 0.0047 - 34ms/epoch - 1ms/step
# Epoch 298/400
# 32/32 - 0s - loss: 0.0054 - 48ms/epoch - 2ms/step
# Epoch 299/400
# 32/32 - 0s - loss: 0.0030 - 47ms/epoch - 1ms/step
# Epoch 300/400
# 32/32 - 0s - loss: 0.0031 - 38ms/epoch - 1ms/step
# Epoch 301/400
# 32/32 - 0s - loss: 0.0056 - 40ms/epoch - 1ms/step
# Epoch 302/400
# 32/32 - 0s - loss: 0.0038 - 51ms/epoch - 2ms/step
# Epoch 303/400
# 32/32 - 0s - loss: 0.0063 - 41ms/epoch - 1ms/step
# Epoch 304/400
# 32/32 - 0s - loss: 0.0028 - 41ms/epoch - 1ms/step
# Epoch 305/400
# 32/32 - 0s - loss: 0.0029 - 41ms/epoch - 1ms/step
# Epoch 306/400
# 32/32 - 0s - loss: 0.0031 - 47ms/epoch - 1ms/step
# Epoch 307/400
# 32/32 - 0s - loss: 0.0136 - 36ms/epoch - 1ms/step
# Epoch 308/400
# 32/32 - 0s - loss: 0.0033 - 46ms/epoch - 1ms/step
# Epoch 309/400
# 32/32 - 0s - loss: 0.0053 - 44ms/epoch - 1ms/step
# Epoch 310/400
# 32/32 - 0s - loss: 0.0037 - 49ms/epoch - 2ms/step
# Epoch 311/400
# 32/32 - 0s - loss: 0.0038 - 59ms/epoch - 2ms/step
# Epoch 312/400
# 32/32 - 0s - loss: 0.0053 - 35ms/epoch - 1ms/step
# Epoch 313/400
# 32/32 - 0s - loss: 0.0034 - 39ms/epoch - 1ms/step
# Epoch 314/400
# 32/32 - 0s - loss: 0.0024 - 40ms/epoch - 1ms/step
# Epoch 315/400
# 32/32 - 0s - loss: 0.0036 - 40ms/epoch - 1ms/step
# Epoch 316/400
# 32/32 - 0s - loss: 0.0019 - 37ms/epoch - 1ms/step
# Epoch 317/400
# 32/32 - 0s - loss: 0.0021 - 44ms/epoch - 1ms/step
# Epoch 318/400
# 32/32 - 0s - loss: 0.0030 - 44ms/epoch - 1ms/step
# Epoch 319/400
# 32/32 - 0s - loss: 0.0032 - 37ms/epoch - 1ms/step
# Epoch 320/400
# 32/32 - 0s - loss: 0.0033 - 44ms/epoch - 1ms/step
# Epoch 321/400
# 32/32 - 0s - loss: 0.0023 - 38ms/epoch - 1ms/step
# Epoch 322/400
# 32/32 - 0s - loss: 0.0032 - 39ms/epoch - 1ms/step
# Epoch 323/400
# 32/32 - 0s - loss: 0.0029 - 44ms/epoch - 1ms/step
# Epoch 324/400
# 32/32 - 0s - loss: 0.0147 - 38ms/epoch - 1ms/step
# Epoch 325/400
# 32/32 - 0s - loss: 0.0023 - 35ms/epoch - 1ms/step
# Epoch 326/400
# 32/32 - 0s - loss: 0.0033 - 39ms/epoch - 1ms/step
# Epoch 327/400
# 32/32 - 0s - loss: 0.0024 - 42ms/epoch - 1ms/step
# Epoch 328/400
# 32/32 - 0s - loss: 0.0022 - 41ms/epoch - 1ms/step
# Epoch 329/400
# 32/32 - 0s - loss: 0.0023 - 37ms/epoch - 1ms/step
# Epoch 330/400
# 32/32 - 0s - loss: 0.0042 - 41ms/epoch - 1ms/step
# Epoch 331/400
# 32/32 - 0s - loss: 0.0024 - 48ms/epoch - 1ms/step
# Epoch 332/400
# 32/32 - 0s - loss: 0.0018 - 44ms/epoch - 1ms/step
# Epoch 333/400
# 32/32 - 0s - loss: 0.0033 - 54ms/epoch - 2ms/step
# Epoch 334/400
# 32/32 - 0s - loss: 0.0024 - 48ms/epoch - 1ms/step
# Epoch 335/400
# 32/32 - 0s - loss: 0.0026 - 38ms/epoch - 1ms/step
# Epoch 336/400
# 32/32 - 0s - loss: 0.0027 - 41ms/epoch - 1ms/step
# Epoch 337/400
# 32/32 - 0s - loss: 0.0025 - 44ms/epoch - 1ms/step
# Epoch 338/400
# 32/32 - 0s - loss: 0.0023 - 38ms/epoch - 1ms/step
# Epoch 339/400
# 32/32 - 0s - loss: 0.0020 - 42ms/epoch - 1ms/step
# Epoch 340/400
# 32/32 - 0s - loss: 0.0018 - 45ms/epoch - 1ms/step
# Epoch 341/400
# 32/32 - 0s - loss: 0.0023 - 39ms/epoch - 1ms/step
# Epoch 342/400
# 32/32 - 0s - loss: 0.0044 - 52ms/epoch - 2ms/step
# Epoch 343/400
# 32/32 - 0s - loss: 0.0021 - 41ms/epoch - 1ms/step
# Epoch 344/400
# 32/32 - 0s - loss: 0.0017 - 42ms/epoch - 1ms/step
# Epoch 345/400
# 32/32 - 0s - loss: 0.0029 - 47ms/epoch - 1ms/step
# Epoch 346/400
# 32/32 - 0s - loss: 0.0021 - 39ms/epoch - 1ms/step
# Epoch 347/400
# 32/32 - 0s - loss: 0.0020 - 40ms/epoch - 1ms/step
# Epoch 348/400
# 32/32 - 0s - loss: 0.0023 - 45ms/epoch - 1ms/step
# Epoch 349/400
# 32/32 - 0s - loss: 0.0025 - 37ms/epoch - 1ms/step
# Epoch 350/400
# 32/32 - 0s - loss: 0.0022 - 40ms/epoch - 1ms/step
# Epoch 351/400
# 32/32 - 0s - loss: 0.0020 - 46ms/epoch - 1ms/step
# Epoch 352/400
# 32/32 - 0s - loss: 0.0018 - 33ms/epoch - 1ms/step
# Epoch 353/400
# 32/32 - 0s - loss: 0.0048 - 44ms/epoch - 1ms/step
# Epoch 354/400
# 32/32 - 0s - loss: 0.0033 - 35ms/epoch - 1ms/step
# Epoch 355/400
# 32/32 - 0s - loss: 0.0025 - 45ms/epoch - 1ms/step
# Epoch 356/400
# 32/32 - 0s - loss: 0.0016 - 33ms/epoch - 1ms/step
# Epoch 357/400
# 32/32 - 0s - loss: 0.0019 - 41ms/epoch - 1ms/step
# Epoch 358/400
# 32/32 - 0s - loss: 0.0028 - 41ms/epoch - 1ms/step
# Epoch 359/400
# 32/32 - 0s - loss: 0.0018 - 35ms/epoch - 1ms/step
# Epoch 360/400
# 32/32 - 0s - loss: 0.0019 - 45ms/epoch - 1ms/step
# Epoch 361/400
# 32/32 - 0s - loss: 0.0016 - 31ms/epoch - 975us/step
# Epoch 362/400
# 32/32 - 0s - loss: 0.0028 - 39ms/epoch - 1ms/step
# Epoch 363/400
# 32/32 - 0s - loss: 0.0015 - 32ms/epoch - 994us/step
# Epoch 364/400
# 32/32 - 0s - loss: 0.0017 - 45ms/epoch - 1ms/step
# Epoch 365/400
# 32/32 - 0s - loss: 0.0014 - 31ms/epoch - 963us/step
# Epoch 366/400
# 32/32 - 0s - loss: 0.0020 - 40ms/epoch - 1ms/step
# Epoch 367/400
# 32/32 - 0s - loss: 0.0020 - 49ms/epoch - 2ms/step
# Epoch 368/400
# 32/32 - 0s - loss: 0.0020 - 33ms/epoch - 1ms/step
# Epoch 369/400
# 32/32 - 0s - loss: 0.0025 - 43ms/epoch - 1ms/step
# Epoch 370/400
# 32/32 - 0s - loss: 0.0016 - 48ms/epoch - 2ms/step
# Epoch 371/400
# 32/32 - 0s - loss: 0.0022 - 38ms/epoch - 1ms/step
# Epoch 372/400
# 32/32 - 0s - loss: 0.0018 - 38ms/epoch - 1ms/step
# Epoch 373/400
# 32/32 - 0s - loss: 0.0031 - 47ms/epoch - 1ms/step
# Epoch 374/400
# 32/32 - 0s - loss: 0.0019 - 38ms/epoch - 1ms/step
# Epoch 375/400
# 32/32 - 0s - loss: 0.0022 - 41ms/epoch - 1ms/step
# Epoch 376/400
# 32/32 - 0s - loss: 0.0013 - 37ms/epoch - 1ms/step
# Epoch 377/400
# 32/32 - 0s - loss: 0.0016 - 45ms/epoch - 1ms/step
# Epoch 378/400
# 32/32 - 0s - loss: 0.0015 - 36ms/epoch - 1ms/step
# Epoch 379/400
# 32/32 - 0s - loss: 0.0014 - 42ms/epoch - 1ms/step
# Epoch 380/400
# 32/32 - 0s - loss: 0.0024 - 36ms/epoch - 1ms/step
# Epoch 381/400
# 32/32 - 0s - loss: 0.0019 - 42ms/epoch - 1ms/step
# Epoch 382/400
# 32/32 - 0s - loss: 0.0020 - 42ms/epoch - 1ms/step
# Epoch 383/400
# 32/32 - 0s - loss: 0.0028 - 36ms/epoch - 1ms/step
# Epoch 384/400
# 32/32 - 0s - loss: 0.0065 - 44ms/epoch - 1ms/step
# Epoch 385/400
# 32/32 - 0s - loss: 0.0020 - 34ms/epoch - 1ms/step
# Epoch 386/400
# 32/32 - 0s - loss: 0.0015 - 45ms/epoch - 1ms/step
# Epoch 387/400
# 32/32 - 0s - loss: 0.0045 - 35ms/epoch - 1ms/step
# Epoch 388/400
# 32/32 - 0s - loss: 0.0014 - 42ms/epoch - 1ms/step
# Epoch 389/400
# 32/32 - 0s - loss: 0.0027 - 35ms/epoch - 1ms/step
# Epoch 390/400
# 32/32 - 0s - loss: 0.0018 - 44ms/epoch - 1ms/step
# Epoch 391/400
# 32/32 - 0s - loss: 0.0016 - 37ms/epoch - 1ms/step
# Epoch 392/400
# 32/32 - 0s - loss: 0.0014 - 49ms/epoch - 2ms/step
# Epoch 393/400
# 32/32 - 0s - loss: 0.0017 - 33ms/epoch - 1ms/step
# Epoch 394/400
# 32/32 - 0s - loss: 0.0017 - 48ms/epoch - 1ms/step
# Epoch 395/400
# 32/32 - 0s - loss: 0.0017 - 33ms/epoch - 1ms/step
# Epoch 396/400
# 32/32 - 0s - loss: 0.0012 - 43ms/epoch - 1ms/step
# Epoch 397/400
# 32/32 - 0s - loss: 0.0013 - 38ms/epoch - 1ms/step
# Epoch 398/400
# 32/32 - 0s - loss: 0.0022 - 45ms/epoch - 1ms/step
# Epoch 399/400
# 32/32 - 0s - loss: 0.0020 - 37ms/epoch - 1ms/step
# Epoch 400/400
# 32/32 - 0s - loss: 0.0026 - 43ms/epoch - 1ms/step
# 32/32 [==============================] - 0s 869us/step
# [array([[ 1.6891062 ,  1.1534187 ,  1.24025   , -0.8990206 , -1.5422024 ,
#          1.7164761 , -1.7759107 ,  2.956834  , -1.444222  , -0.21430461,
#         -0.9980576 ,  2.0278516 ]], dtype=float32), array([ 0.13886146, -1.4662255 , -3.444463  ,  2.1692657 ,  0.71592987,
#         0.07053423, -3.2089899 ,  1.6523339 , -1.478024  ,  1.1416632 ,
#        -0.6045837 ,  5.83204   ], dtype=float32)]
# [array([[ 0.2480498 , -0.3541129 , -0.03272399, -0.12323329,  0.14038809,
#         -0.2737734 , -0.2804914 , -0.68368876, -0.05648512,  0.40776497,
#          0.14495951,  0.29892597],
#        [-0.37435302,  1.1646044 ,  0.8017266 ,  0.42847565, -0.1314743 ,
#          0.38091695,  0.6446879 , -0.28432643, -0.45363164, -1.6271367 ,
#         -0.4868078 , -0.1101988 ],
#        [-0.32743794,  0.09895156,  0.4971679 ,  1.4959958 ,  1.1621168 ,
#         -0.02025383,  2.1481078 , -0.6564784 ,  0.1671616 , -1.5715381 ,
#         -1.0441778 ,  0.04710858],
#        [ 0.50789994, -1.2736572 , -1.408314  , -0.6729829 , -1.2574712 ,
#          0.1018873 , -1.3313701 ,  0.14823498,  0.17608376,  0.7291319 ,
#         -0.1873656 ,  0.07216141],
#        [ 0.25336966, -0.82615215, -1.2315444 ,  0.08726444,  0.5383058 ,
#          0.15150015, -0.2274759 ,  0.2829794 , -0.6483013 ,  0.15461233,
#         -0.43345276, -0.02625709],
#        [ 0.01695254,  0.5998664 ,  0.11568014, -0.5155198 ,  0.87323403,
#          0.35311908, -0.29509822, -0.35803315,  0.2584939 , -0.22844836,
#          0.34203422,  0.50769156],
#        [-2.249698  ,  0.44222504, -0.45773712, -2.1223726 , -0.396052  ,
#          1.9359503 ,  0.95733607,  0.89688015,  2.3665407 ,  0.6387535 ,
#         -0.39022762, -0.77709407],
#        [-0.42024127, -0.36995283,  0.5452182 , -1.3145459 ,  0.30048907,
#         -0.06358907,  0.2287664 , -1.5332685 ,  0.5650022 , -0.68962634,
#         -0.43031642,  0.73865926],
#        [-0.87506306, -0.08786231, -0.54203176, -1.57734   ,  0.739581  ,
#          0.8980855 , -0.03044882,  0.0210561 ,  0.6470965 ,  0.1431152 ,
#         -0.09210272, -0.42417827],
#        [-0.01842049, -0.7284982 , -0.614277  , -0.8874849 , -1.0411277 ,
#          0.22971927, -0.864902  , -0.16150327, -0.89248717,  0.86889994,
#         -0.41839337, -0.83314395],
#        [-0.40595606, -0.02775894,  0.04688606, -0.7719415 ,  0.08514649,
#          0.12272455, -0.13859151,  0.36556682,  0.69075245, -0.23306601,
#          0.02136599,  0.547522  ],
#        [ 3.120292  ,  0.31493363, -0.57332194, -0.5864367 ,  0.33780053,
#         -0.71209043, -0.24890871,  0.17431615,  3.3998575 ,  0.7724799 ,
#          0.14581475,  3.6900985 ]], dtype=float32), array([-2.548122  ,  0.6204808 ,  0.28179303,  0.5770856 , -0.52593374,
#         0.0194785 , -0.03492377,  0.19794628, -1.1158844 , -0.16210882,
#        -0.5414499 ,  0.37957108], dtype=float32)]
# [array([[-3.5529647 ],
#        [ 1.5065105 ],
#        [ 2.1167047 ],
#        [-2.8504095 ],
#        [ 1.1211529 ],
#        [-0.8257981 ],
#        [ 2.0003119 ],
#        [ 0.88690275],
#        [-2.619226  ],
#        [ 1.7961066 ],
#        [-0.5126997 ],
#        [ 3.7165537 ]], dtype=float32), array([1.2991939], dtype=float32)]

# %% [markdown]
# # Домашнее задание
# 1. Проработайте блокнот Jupyter содержащий пример, демонстрировавшийся на занятии.
# 2. Повторите решение задачи для индивидуального варианта функции, поэкспериментируйте со структурой сети (количество скрытых слоев, нейронов в слоях) до получения высокой точности аппроксимации.
