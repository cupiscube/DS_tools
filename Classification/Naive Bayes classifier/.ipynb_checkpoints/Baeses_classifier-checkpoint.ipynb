# %% [markdown]
# # Наивный Баесовский классификатор

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import GaussianNB # Гаусовский наивный классификатор

# %%
X, y = load_iris(return_X_y=True) # y - labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0) # Делим данные

# %%
gnb = GaussianNB() # Создаем классификатор

# %%
y_pred = gnb.fit(X_train, y_train).predict(X_test) # Применяем. Тренируем и делаем предсказаение

# %%
print('Number of mislabeled points out of a total %d points: %d' % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 75 points: 4

# %%
score = gnb.score(X_test, y_test) # Проверяем качество классификатора
score
# Out:
# 0.9466666666666667

# %%
# Объединим тренировочнуб и тестовые части
X1 = np.vstack([X_train, X_test])
y1 = np.vstack([y_train, y_test])

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

cm_bright = ListedColormap(["#FF0000", "#0000FF"])
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(221)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='viridis', edgecolors="k")

ax = fig.add_subplot(222)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap='viridis', edgecolors="k", alpha=0.6)

ax = fig.add_subplot(223)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolors="k")

ax = fig.add_subplot(224)
plt.scatter(X1[:, 0], X1[:, 1], c=y1, cmap='viridis', edgecolors="k")
