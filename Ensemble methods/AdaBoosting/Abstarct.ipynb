# %% [raw]
# Бустинг комбинирует слабые модели, которые последовательно обучаются на ошибках предыдущих моделей.

# %%
from IPython.display import Image
# %matplotlib inline

# %%
Image(filename='images/ans_09_rus.png', width=400)

# %%
Image(filename='images/ans_10_rus.png', width=500) # Russian version
